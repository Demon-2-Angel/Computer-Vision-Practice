# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# ## Reading an Image

# %% [markdown]
# img = cv2.imread("white lotus.jpg", cv2.IMREAD_GRAYSCALE) -> Produces a Grayscale Image\
# img = cv2.imread("white lotus.jpg", cv2.IMREAD_UNCHANGED) -> Produces a Original Image\
# img = cv2.imread("white lotus.jpg", cv2.IMREAD_COLOR) -> natural Image (Transperancy neglected)

# %%
img1 = cv2.imread("Sheild Hero.jpg")
img1_rgb = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
plt.title("Original")
plt.imshow(img1_rgb)

# %%
img = cv2.imread("Sheild Hero.jpg", cv2.IMREAD_GRAYSCALE)
plt.title("Gray Scaled Image")
plt.imshow(img)

# %% [markdown]
# ## Colour Image to Grayscale

# %%
src = "white lotus.jpg"
img3 = cv2.imread(src)
cv2.imshow("Sheild Hero", img3)

#opening image new window and closing it
cv2.waitKey(0)
cv2.destroyAllWindows()

#if image not found
if img3 is None:
    print("Couldn't find the image", img3)
    exit(0) 
    
    
Gray = cv2.cvtColor(img3, cv2.COLOR_BGR2GRAY)
cv2.imshow("Grayscaled", Gray)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Seperating  BGR & combining BGR Channels

# %%
blue, green, red = cv2.split(img3)
cv2.imshow('Blue-Gray Scale', blue)
cv2.waitKey(0)
cv2.destroyAllWindows()

cv2.imshow('Green-Gray Scale', green)
cv2.waitKey(0)
cv2.destroyAllWindows()

cv2.imshow('Red-Gray Scale', red)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#creating dummy 3D-array
blue_channel = np.zeros(img3.shape, img3.dtype)
green_channel = np.zeros(img3.shape, img3.dtype)
red_channel = np.zeros(img3.shape, img3.dtype)

cv2.mixChannels([blue, red, green], [blue_channel], [0,0])
cv2.mixChannels([blue, red, green], [green_channel], [1,1])
cv2.mixChannels([blue, red, green], [red_channel], [2,2])

cv2.imshow("Blue Channel", blue_channel)
cv2.waitKey(0)
cv2.destroyAllWindows()

cv2.imshow("Green Channel", green_channel)
cv2.waitKey(0)
cv2.destroyAllWindows()

cv2.imshow("Red Channel", red_channel)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Blurring an Image

# %%
blured_image= cv2.medianBlur(img1,19)
"""cv2.imshow("Blured Sheild Hero",blured_image)
cv2.waitKey(0)
cv2.destroyAllWindows()"""
plt.imshow(blured_image)
