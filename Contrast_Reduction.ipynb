# %%
import cv2
from matplotlib import pyplot as plt
import PIL as pillow
import numpy as np

# %%
img = cv2.imread(r"C:\Users\aniru\Machine Learning\Computer Vision\white lotus.jpg")
plt.imshow(img)

# %% [markdown]
# ## Contrast Reduction using Bitwise-Not

# %% [markdown]
# It flips the 0 and 1s in the image

# %%
image = cv2.bitwise_not(img)
plt.imshow(image)
cv2.imwrite("output.jpeg", image)
# Out:
# True

# %%
from PIL import Image
from numpy import array

im_1 = Image.open(r"C:\Users\aniru\Machine Learning\Computer Vision\white lotus.jpg")
ar_1 = array(im_1)
ar_1

im_2 = Image.open("output.jpeg")
ar_2 = array(im_2)
ar_2
# Out:
# array([[[220, 216, 207],
#         [220, 216, 207],
#         [221, 217, 208],
#         ...,
#         [254, 241, 250],
#         [254, 241, 250],
#         [255, 242, 251]],
#
#        [[221, 217, 208],
#         [221, 217, 208],
#         [221, 217, 208],
#         ...,
#         [253, 240, 249],
#         [253, 240, 249],
#         [254, 241, 250]],
#
#        [[222, 217, 211],
#         [222, 217, 211],
#         [222, 217, 211],
#         ...,
#         [252, 239, 248],
#         [252, 239, 248],
#         [252, 239, 248]],
#
#        ...,
#
#        [[244, 217, 232],
#         [253, 226, 241],
#         [255, 228, 245],
#         ...,
#         [255, 235, 246],
#         [255, 235, 246],
#         [255, 235, 246]],
#
#        [[244, 217, 232],
#         [253, 226, 241],
#         [254, 227, 244],
#         ...,
#         [254, 234, 245],
#         [254, 234, 245],
#         [254, 234, 245]],
#
#        [[245, 218, 233],
#         [253, 226, 241],
#         [254, 227, 244],
# ...
